# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhya111205/principle-of-datascience/blob/main/mydataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Use a car.csv dataset and perform exploratory data analysis using pandas and matplotlib library functions to manipulate and vizualize the data and find insights**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1.Import the library

# %%
#Import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# 2.Load the dataset using pandas read_csv() function

# %%
#Load cars.csv dataset
students=pd.read_csv('/content/drive/MyDrive/principle of datascience/mydataset2.csv')
students
# Out:
#     Register NO                  Name Course            Department  \
# 0     192455801         Aishwarya Rai    MSc   Software Technology
# 1     192455802  Aneesa Parween A K M    MCA  Computer Application
# 2     192455803               Babitha    MSc               Physics
# 3     192455804          Divyashree U    MCA  Computer Application
# 4     192455805              Krithika    MSc   Software Technology
# 5     192455806             Nireeksha    MSc   Software Technology
# 6     192455807             Preethika    BEd               Kannada
# 7     192455808              Rithesh     MSc        Marine Geology
# 8     192455809       Sandhya laxmi k    MSc      Computer Science
# 9     192455809       Sandhya laxmi k    MSc      Computer Science
# 10    192455810              Shashank    MCA      Computer Science
# 11    192455811                Shreya    MSc        Cyber Security
# 12    192455812            Tejashwini    MCA  Computer Application
# ...

# %%
#rows containing duplicate data
duplicate_rows_student=students[students.duplicated()]
print("Number of duplicate rows:",duplicate_rows_student.shape)
# Out:
# Number of duplicate rows: (1, 11)

# %%
#drop the duplicates
students.drop_duplicates()
students.head(15)
# Out:
#     Register NO                  Name Course            Department  \
# 0     192455801         Aishwarya Rai    MSc   Software Technology
# 1     192455802  Aneesa Parween A K M    MCA  Computer Application
# 2     192455803               Babitha    MSc               Physics
# 3     192455804          Divyashree U    MCA  Computer Application
# 4     192455805              Krithika    MSc   Software Technology
# 5     192455806             Nireeksha    MSc   Software Technology
# 6     192455807             Preethika    BEd               Kannada
# 7     192455808              Rithesh     MSc        Marine Geology
# 8     192455809       Sandhya laxmi k    MSc      Computer Science
# 9     192455809       Sandhya laxmi k    MSc      Computer Science
# 10    192455810              Shashank    MCA      Computer Science
# 11    192455811                Shreya    MSc        Cyber Security
# 12    192455812            Tejashwini    MCA  Computer Application
# ...

# %%
#rows containing duplicate data
duplicate_rows_student=students[students.duplicated()]
print("Number of duplicate rows:",duplicate_rows_student.shape)
# Out:
# Number of duplicate rows: (1, 11)

# %%
#drop the duplicates
st=students.drop_duplicates()
st
# Out:
#     Register NO                  Name Course            Department  \
# 0     192455801         Aishwarya Rai    MSc   Software Technology
# 1     192455802  Aneesa Parween A K M    MCA  Computer Application
# 2     192455803               Babitha    MSc               Physics
# 3     192455804          Divyashree U    MCA  Computer Application
# 4     192455805              Krithika    MSc   Software Technology
# 5     192455806             Nireeksha    MSc   Software Technology
# 6     192455807             Preethika    BEd               Kannada
# 7     192455808              Rithesh     MSc        Marine Geology
# 8     192455809       Sandhya laxmi k    MSc      Computer Science
# 10    192455810              Shashank    MCA      Computer Science
# 11    192455811                Shreya    MSc        Cyber Security
# 12    192455812            Tejashwini    MCA  Computer Application
# 13    192455813            Aishwarya     BEd               Physics
# ...

# %%
st.count()
# Out:
# Register NO               21
# Name                      20
# Course                    20
# Department                19
# Institution               20
# Address                   20
# Phone No                  20
# Email\n Address           20
# Attendance                20
# Marks\n(in percentage)    20
# Result                    20
# dtype: int64

# %% [markdown]
# 3.Display the head of the dataset using head() function

# %%
#display the head of the dataset
st.head()
# Out:
#    Register NO                  Name Course            Department  \
# 0    192455801         Aishwarya Rai    MSc   Software Technology
# 1    192455802  Aneesa Parween A K M    MCA  Computer Application
# 2    192455803               Babitha    MSc               Physics
# 3    192455804          Divyashree U    MCA  Computer Application
# 4    192455805              Krithika    MSc   Software Technology
#
#             Institution    Address      Phone No            Email\n Address  \
# 0             Aloshious  Kasaragod  7.894561e+09   aishwaryarai55@gmail.com
# 1            Shree Devi     Uppala  7.418530e+09  aneesaparween86@gmail.com
# 2  Mangalore University     Kumbla  9.638521e+09  babithashetty45@gmail.com
# 3             Aloshious     Kumbla  8.527420e+09    divyashreeu85@gmail.com
# 4             Aloshious     Kumbla  7.412590e+09       krithika45@gmail.com
#
#   Attendance Marks\n(in percentage) Result
# 0        78%                    80%   Pass
# ...

# %% [markdown]
# 4.Display the bottom 5 row from the dataset using tail() function

# %%
#Display the bottom 5 rows
st.tail(5)
# Out:
#     Register NO     Name Course   Department           Institution    Address  \
# 17    192455817   Sushma    MSc  Mathematics     Mysore University  Mangalore
# 18    192455818  Pallavi    MSc  Mathematics  Mangalore University     Mysore
# 19    192455819  Vidisha    MCA          NaN             Aloshious     Mysore
# 20    192455820   Vinyas    MSc  Mathematics  Mangalore University  Mangalore
# 21    192455821      NaN    NaN          NaN                   NaN        NaN
#
#         Phone No              Email\n Address Attendance  \
# 17  9.223790e+09           Sushma61@gmail.com        94%
# 18  9.385077e+09  Pallavimanglore@65gmail.com        95%
# 19  9.546364e+09         Vidisha876@gmail.com        96%
# 20  9.707651e+09           Vinyas76@gmail.com        97%
# 21           NaN                          NaN        NaN
#
#    Marks\n(in percentage) Result
# 17                    85%   Pass
# 18                    69%   Pass
# 19                    63%   Pass
# ...

# %% [markdown]
# 5.Print summary statistical of data set using the describe() function

# %%
#Analytical summary of dataset
st.describe(include='all')
# Out:
#          Register NO        Name Course            Department  \
# count   2.100000e+01          20     20                    19
# unique           NaN          19      3                     9
# top              NaN  Tejashwini    MSc  Computer Application
# freq             NaN           2     11                     4
# mean    1.924558e+08         NaN    NaN                   NaN
# std     6.204837e+00         NaN    NaN                   NaN
# min     1.924558e+08         NaN    NaN                   NaN
# 25%     1.924558e+08         NaN    NaN                   NaN
# 50%     1.924558e+08         NaN    NaN                   NaN
# 75%     1.924558e+08         NaN    NaN                   NaN
# max     1.924558e+08         NaN    NaN                   NaN
#
#                  Institution    Address      Phone No  \
# count                     20         20  2.000000e+01
# unique                     6          7           NaN
# top     Mangalore University  Mangalore           NaN
# ...

# %% [markdown]
# 6.plot a histogram for all the variables

# %%
st.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Register NO'}>,
#         <Axes: title={'center': 'Phone No'}>]], dtype=object)

# %% [markdown]
# 7.Box plot to vizualize the relationship between model and size

# %% [markdown]
# 8.Build a pairplot using subborn library

# %% [markdown]
# 9.Drop irrelevent columns from the datset using drop() function

# %%
#drop irrelevent column
st=st.drop(['Address'],axis=1)
st.head(5)
# Out:
#    Register NO                  Name Course            Department  \
# 0    192455801         Aishwarya Rai    MSc   Software Technology
# 1    192455802  Aneesa Parween A K M    MCA  Computer Application
# 2    192455803               Babitha    MSc               Physics
# 3    192455804          Divyashree U    MCA  Computer Application
# 4    192455805              Krithika    MSc   Software Technology
#
#             Institution      Phone No            Email\n Address Attendance  \
# 0             Aloshious  7.894561e+09   aishwaryarai55@gmail.com        78%
# 1            Shree Devi  7.418530e+09  aneesaparween86@gmail.com        82%
# 2  Mangalore University  9.638521e+09  babithashetty45@gmail.com        85%
# 3             Aloshious  8.527420e+09    divyashreeu85@gmail.com        55%
# 4             Aloshious  7.412590e+09       krithika45@gmail.com        95%
#
#   Marks\n(in percentage) Result
# 0                    80%   Pass
# 1                    71%   Pass
# ...

# %% [markdown]
# 10.use rename() function to rename

# %%
#Rename column name
st=st.rename(columns={"Name":"Student_Name","Course":"Course_Name","Department":"Dept"})
st.head(5)
# Out:
#    Register NO          Student_Name Course_Name                  Dept  \
# 0    192455801         Aishwarya Rai         MSc   Software Technology
# 1    192455802  Aneesa Parween A K M         MCA  Computer Application
# 2    192455803               Babitha         MSc               Physics
# 3    192455804          Divyashree U         MCA  Computer Application
# 4    192455805              Krithika         MSc   Software Technology
#
#             Institution      Phone No            Email\n Address Attendance  \
# 0             Aloshious  7.894561e+09   aishwaryarai55@gmail.com        78%
# 1            Shree Devi  7.418530e+09  aneesaparween86@gmail.com        82%
# 2  Mangalore University  9.638521e+09  babithashetty45@gmail.com        85%
# 3             Aloshious  8.527420e+09    divyashreeu85@gmail.com        55%
# 4             Aloshious  7.412590e+09       krithika45@gmail.com        95%
#
#   Marks\n(in percentage) Result
# 0                    80%   Pass
# ...

# %% [markdown]
# 11.Print the total number of duplicate row

# %%
#rows containing duplicate data
duplicate_rows_student=st[st.duplicated()]
print("Number of duplicate rows:",duplicate_rows_student.shape)
# Out:
# Number of duplicate rows: (0, 10)

# %%
#count the rows before removing the data
students.count()
# Out:
# Register NO               22
# Student_Name              21
# Course_Name               21
# Dept                      20
# Institution               21
# Phone No                  21
# Email\n Address           21
# Attendance                21
# Marks\n(in percentage)    21
# Result                    21
# dtype: int64

# %% [markdown]
# 12.Remove the duplicate rows using drop_duplicates () function

# %%
#drop the duplicates
students.drop_duplicates()
students.head()
# Out:
#    Register NO          Student_Name Course_Name                  Dept  \
# 0    192455801         Aishwarya Rai         MSc   Software Technology
# 1    192455802  Aneesa Parween A K M         MCA  Computer Application
# 2    192455803               Babitha         MSc               Physics
# 3    192455804          Divyashree U         MCA  Computer Application
# 4    192455805              Krithika         MSc   Software Technology
#
#             Institution      Phone No            Email\n Address Attendance  \
# 0             Aloshious  7.894561e+09   aishwaryarai55@gmail.com        78%
# 1            Shree Devi  7.418530e+09  aneesaparween86@gmail.com        82%
# 2  Mangalore University  9.638521e+09  babithashetty45@gmail.com        85%
# 3             Aloshious  8.527420e+09    divyashreeu85@gmail.com        55%
# 4             Aloshious  7.412590e+09       krithika45@gmail.com        95%
#
#   Marks\n(in percentage) Result
# 0                    80%   Pass
# ...

# %%
students.count()
# Out:
# Register NO               22
# Student_Name              21
# Course_Name               21
# Dept                      20
# Institution               21
# Phone No                  21
# Email\n Address           21
# Attendance                21
# Marks\n(in percentage)    21
# Result                    21
# dtype: int64

# %% [markdown]
# 13.Drop the missing values from th dataset

# %%
#find the null values
print(students.isnull().sum())
# Out:
# Register NO               0
# Student_Name              1
# Course_Name               1
# Dept                      2
# Institution               1
# Phone No                  1
# Email\n Address           1
# Attendance                1
# Marks\n(in percentage)    1
# Result                    1
# dtype: int64

# %%
#drop the missing value
students=students.dropna()
students.count()
# Out:
# Register NO               20
# Student_Name              20
# Course_Name               20
# Dept                      20
# Institution               20
# Phone No                  20
# Email\n Address           20
# Attendance                20
# Marks\n(in percentage)    20
# Result                    20
# dtype: int64

# %% [markdown]
# 14.Plot a histogram to find the number of cars per brand

# %%
students.Result.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("Number of Students by Result")
plt.ylabel('Nuber of Student')
plt.xlabel('Result')
# Out:
# Text(0.5, 0, 'Result')

# %% [markdown]
# 15.Draw a correlation plot between the variables

# %%
#find the relation between the value
plt.figure(figsize=(20,10))
s=students.corr()
sns.heatmap(s,cmap="BrBG",annot=True)
s
# Out:
# <ipython-input-37-de204237295c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   s=students.corr()
#              Register NO  Phone No
# Register NO     1.000000  0.616449
# Phone No        0.616449  1.000000
