# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhya111205/principle-of-datascience/blob/main/bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 1.Import data

# %%
import pandas as pd
from pandas import DataFrame
bank=pd.read_csv('/content/drive/MyDrive/principle of datascience/ datasets/bank2.csv')
bank
# Out:
#            Account No       DATE               TRANSACTION DETAILS  CHQ.NO.  \
# 0       409000611074'  29-Jun-17  TRF FROM  Indiaforensic SERVICES      NaN
# 1       409000611074'  05-Jul-17  TRF FROM  Indiaforensic SERVICES      NaN
# 2       409000611074'  18-Jul-17        FDRL/INTERNAL FUND TRANSFE      NaN
# 3       409000611074'  01-Aug-17   TRF FRM  Indiaforensic SERVICES      NaN
# 4       409000611074'  16-Aug-17        FDRL/INTERNAL FUND TRANSFE      NaN
# ...               ...        ...                               ...      ...
# 116196  409000362497'  05-Mar-19  TRF TO 1196428  Indiaforensic SE      NaN
# 116197  409000362497'  05-Mar-19        FDRL/INTERNAL FUND TRANSFE      NaN
# 116198  409000362497'  05-Mar-19        FDRL/INTERNAL FUND TRANSFE      NaN
# 116199  409000362497'  05-Mar-19                 IMPS 05-03-20194C      NaN
# 116200  409000362497'  05-Mar-19         Sweep Trf To: 40900036427      NaN
#
# ...

# %%
bankxl=pd.read_excel('/content/drive/MyDrive/principle of datascience/ datasets/bank1.xlsx')
bankxl.head(5)
# Out:
#       Account No       DATE               TRANSACTION DETAILS  CHQ.NO.  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES      NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES      NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE      NaN
# 3  409000611074' 2017-08-01   TRF FRM  Indiaforensic SERVICES      NaN
# 4  409000611074' 2017-08-16        FDRL/INTERNAL FUND TRANSFE      NaN
#
#   VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  .
# 0 2017-06-29             NaN    1000000.0    1000000.0  .
# 1 2017-07-05             NaN    1000000.0    2000000.0  .
# 2 2017-07-18             NaN     500000.0    2500000.0  .
# 3 2017-08-01             NaN    3000000.0    5500000.0  .
# 4 2017-08-16             NaN     500000.0    6000000.0  .

# %% [markdown]
# 2.DataFrame property

# %%
bank.shape
# Out:
# (116201, 9)

# %%
bank.describe()
# Out:
#              CHQ.NO.
# count     905.000000
# mean   791614.503867
# std    151205.932910
# min         1.000000
# 25%    704231.000000
# 50%    873812.000000
# 75%    874167.000000
# max    874525.000000

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116201 entries, 0 to 116200
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Account No           116201 non-null  object
#  1   DATE                 116201 non-null  object
#  2   TRANSACTION DETAILS  113702 non-null  object
#  3   CHQ.NO.              905 non-null     float64
#  4   VALUE DATE           116201 non-null  object
#  5    WITHDRAWAL AMT      53549 non-null   object
#  6    DEPOSIT AMT         62652 non-null   object
#  7   BALANCE AMT          116201 non-null  object
#  8   .                    116201 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 8.0+ MB

# %% [markdown]
# 3.converting string to category

# %%
bank['Account No']=bank['Account No'].astype('category')
bank['BALANCE AMT']=bank['BALANCE AMT'].astype('category')
bank.describe(include='category')
# Out:
#        Account No       DATE           BALANCE AMT
# count      116201     116201                116201
# unique         10       1294                115143
# top      1196428'  27-Jul-17   -1,53,62,00,539.43
# freq        48779        567                    57

# %% [markdown]
# 4.Type conversion

# %%
for col in['TRANSACTION DETAILS','DATE']:
      bank[col]=bank[col].astype('category')
      bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116201 entries, 0 to 116200
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Account No           116201 non-null  category
#  1   DATE                 116201 non-null  category
#  2   TRANSACTION DETAILS  113702 non-null  category
#  3   CHQ.NO.              905 non-null     float64
#  4   VALUE DATE           116201 non-null  object
#  5    WITHDRAWAL AMT      53549 non-null   object
#  6    DEPOSIT AMT         62652 non-null   object
#  7   BALANCE AMT          116201 non-null  category
#  8   .                    116201 non-null  object
# dtypes: category(4), float64(1), object(4)
# memory usage: 11.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116201 entries, 0 to 116200
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
# ...

# %%
for col in['BALANCE AMT']:
      bank[col]=bank[col].astype('float64')
      bank.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/categorical.py in astype(self, dtype, copy)
#     550             try:
# --> 551                 new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     552                 fill_value = self.categories._na_value
#
# ValueError: could not convert string to float: ' -1,00,00,11,840.77 '
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-e0e769c3cd3d> in <cell line: 1>()
#       1 for col in['BALANCE AMT']:
# ----> 2       bank[col]=bank[col].astype('float64')
#       3       bank.info()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
# ...

# %% [markdown]
# 5.Basic descriptive status

# %%
bank["CHQ.NO."].mean(),bank["CHQ.NO."].min(),bank["CHQ.NO."].max()
# Out:
# (791614.5038674034, 1.0, 874525.0)

# %%
bank.describe()
# Out:
#              CHQ.NO.
# count     905.000000
# mean   791614.503867
# std    151205.932910
# min         1.000000
# 25%    704231.000000
# 50%    873812.000000
# 75%    874167.000000
# max    874525.000000

# %% [markdown]
# 9.Histogram on seaborn

# %%
import seaborn as sns
sns.histplot(x=bank['Account No'])
# Out:
# <Axes: xlabel='Account No', ylabel='Count'>

# %%
sns.histplot(x=bank['Account No'],bins=10,kde=True,stat="probability",color='red')
# Out:
# <Axes: xlabel='Account No', ylabel='Probability'>

# %% [markdown]
# 7.Filtering data

# %%
b=bank['TRANSACTION DETAILS']=='IMPS 05-03-20194C'
b
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 116196    False
# 116197    False
# 116198    False
# 116199     True
# 116200    False
# Name: TRANSACTION DETAILS, Length: 116201, dtype: bool

# %%
b=bank[bank['TRANSACTION DETAILS']=='TRF FROM Indiaforensic SERVICES']
b
# Out:
#            Account No       DATE              TRANSACTION DETAILS  CHQ.NO.  \
# 5226    409000438611'  04-Apr-18  TRF FROM Indiaforensic SERVICES      NaN
# 5227    409000438611'  04-Apr-18  TRF FROM Indiaforensic SERVICES      NaN
# 30244        1196711'  26-Oct-15  TRF FROM Indiaforensic SERVICES      NaN
# 30245        1196711'  26-Oct-15  TRF FROM Indiaforensic SERVICES      NaN
# 31512        1196711'  15-Dec-15  TRF FROM Indiaforensic SERVICES      NaN
# ...               ...        ...                              ...      ...
# 103398  409000362497'  07-Apr-17  TRF FROM Indiaforensic SERVICES      NaN
# 104474  409000362497'  20-May-17  TRF FROM Indiaforensic SERVICES      NaN
# 104475  409000362497'  20-May-17  TRF FROM Indiaforensic SERVICES      NaN
# 108361  409000362497'  16-Oct-17  TRF FROM Indiaforensic SERVICES      NaN
# 108362  409000362497'  16-Oct-17  TRF FROM Indiaforensic SERVICES      NaN
#
# ...

# %%
from pandas import DataFrame

# %%
trf_service=bank[bank['TRANSACTION DETAILS']=='TRF FROM Indiaforensic SERVICES']
type(trf_service)
pd.DataFrame(trf_service)
# Out:
#            Account No       DATE              TRANSACTION DETAILS  CHQ.NO.  \
# 5226    409000438611'  04-Apr-18  TRF FROM Indiaforensic SERVICES      NaN
# 5227    409000438611'  04-Apr-18  TRF FROM Indiaforensic SERVICES      NaN
# 30244        1196711'  26-Oct-15  TRF FROM Indiaforensic SERVICES      NaN
# 30245        1196711'  26-Oct-15  TRF FROM Indiaforensic SERVICES      NaN
# 31512        1196711'  15-Dec-15  TRF FROM Indiaforensic SERVICES      NaN
# ...               ...        ...                              ...      ...
# 103398  409000362497'  07-Apr-17  TRF FROM Indiaforensic SERVICES      NaN
# 104474  409000362497'  20-May-17  TRF FROM Indiaforensic SERVICES      NaN
# 104475  409000362497'  20-May-17  TRF FROM Indiaforensic SERVICES      NaN
# 108361  409000362497'  16-Oct-17  TRF FROM Indiaforensic SERVICES      NaN
# 108362  409000362497'  16-Oct-17  TRF FROM Indiaforensic SERVICES      NaN
#
# ...

# %%
trf_service['CHQ.NO.'].mean()
# Out:
# nan

# %%
round(trf_service['CHQ.NO.'].mean(),2)
# Out:
# nan

# %% [markdown]
# 9.Complex Filtering critaria

# %%
(bank['TRANSACTION DETAILS']=='IMPS 05-03-20194C')&(bank['CHQ.NO.']==1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 116196    False
# 116197    False
# 116198    False
# 116199    False
# 116200    False
# Length: 116201, dtype: bool

# %%
bank[(bank['TRANSACTION DETAILS']=='IMPS 05-03-20194C')&(bank['CHQ.NO.']==1)].shape
# Out:
# (0, 9)

# %% [markdown]
# Fitering by list

# %%
bank[bank['CHQ.NO.']>=4]
# Out:
#           Account No       DATE               TRANSACTION DETAILS   CHQ.NO.  \
# 2909   409000425051'  12-Jun-17  Indiaforensic SERVICES I P LTD P       5.0
# 2910   409000425051'  12-Jun-17  Indiaforensic SERVICES INDIA PVT       6.0
# 2911   409000425051'  12-Jun-17  Indiaforensic SERVICES I P LTD R       4.0
# 2913   409000425051'  14-Jun-17  Indiaforensic SERVICES INDIA PVT       9.0
# 2914   409000425051'  14-Jun-17  Indiaforensic SERVICES INDIA PVT       7.0
# ...              ...        ...                               ...       ...
# 86064       1196428'  20-Feb-19   NEFT/000067554033/Indiaforensic  704426.0
# 86243       1196428'  28-Feb-19          MAX BUPA HELATH INSURACE  704383.0
# 86278       1196428'  01-Mar-19             CASHPMT/SELF/GURGAON/  704391.0
# 86296       1196428'  02-Mar-19          VODAFONE MOBILE SERVICES  704389.0
# 86297       1196428'  02-Mar-19          VODAFONE MOBILE SERVICES  704388.0
#
# ...

# %%
mgmt=[4,5,6]
bank[bank['CHQ.NO.'].isin(mgmt)]
# Out:
#           Account No       DATE               TRANSACTION DETAILS  CHQ.NO.  \
# 2909   409000425051'  12-Jun-17  Indiaforensic SERVICES I P LTD P      5.0
# 2910   409000425051'  12-Jun-17  Indiaforensic SERVICES INDIA PVT      6.0
# 2911   409000425051'  12-Jun-17  Indiaforensic SERVICES I P LTD R      4.0
# 6227   409000438611'  21-Sep-18   NEFT/000050794506/Indiaforensic      4.0
# 6229   409000438611'  21-Sep-18   NEFT/000050794647/Indiaforensic      5.0
# 22208  409000438620'  26-Jun-18      RTGS/YESBH18177599358/Indfor      5.0
# 22210  409000438620'  26-Jun-18      RTGS/YESBH18177600906/Indfor      4.0
#
#       VALUE DATE   WITHDRAWAL AMT   DEPOSIT AMT          BALANCE AMT  .
# 2909   12-Jun-17           200.00            NaN        6,00,687.85   .
# 2910   12-Jun-17           200.00            NaN        6,00,487.85   .
# 2911   12-Jun-17           200.00            NaN        6,00,287.85   .
# 6227   21-Sep-18   1,00,00,000.00            NaN   -54,22,97,395.59   .
# ...
